# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# import csv and load into a DataFrame

city_weather_path = "city_weather_clean.csv"

city_weather = pd.read_csv(city_weather_path)

city_weather.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  carnarvon -24.87  113.63    51.800     100.0        17.0        3.10
# 1      korla  41.76   86.15    80.006      45.0        49.0        2.24
# 2    qaanaaq  77.48  -69.36    42.188      62.0       100.0        3.12
# 3      okato -39.20  173.88    53.996      58.0        92.0        2.68
# 4    kahului  20.89 -156.47    87.800      48.0        20.0        9.80
#
#   Country        Date
# 0      AU  08-17-2020
# 1      CN  08-17-2020
# 2      GL  08-17-2020
# 3      NZ  08-17-2020
# 4      US  08-17-2020

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key = g_key)

# %%
city_weather['Location'] = city_weather[['Lat','Lng']].apply(tuple, axis = 1)

# %%
city_weather.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  carnarvon -24.87  113.63    51.800     100.0        17.0        3.10
# 1      korla  41.76   86.15    80.006      45.0        49.0        2.24
# 2    qaanaaq  77.48  -69.36    42.188      62.0       100.0        3.12
# 3      okato -39.20  173.88    53.996      58.0        92.0        2.68
# 4    kahului  20.89 -156.47    87.800      48.0        20.0        9.80
#
#   Country        Date          Location
# 0      AU  08-17-2020  (-24.87, 113.63)
# 1      CN  08-17-2020    (41.76, 86.15)
# 2      GL  08-17-2020   (77.48, -69.36)
# 3      NZ  08-17-2020   (-39.2, 173.88)
# 4      US  08-17-2020  (20.89, -156.47)

# %%
locations = city_weather['Location']
humidity = city_weather['Humidity']

# %%
fig = gmaps.figure(center = (48.0,0.0), zoom_level = 1.5)

heat_layer = gmaps.heatmap_layer(
                locations,
                weights = humidity,
                max_intensity = 100,
                dissipating = False,
                point_radius = 1.75,
                opacity = 1,
                gradient = None)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_vacation_cities = city_weather[(city_weather['Max Temp'] < 80) & (city_weather['Max Temp'] > 70) & (city_weather['Wind Speed'] < 10) & (city_weather['Cloudiness'] == 0)]

# %%
ideal_vacation_cities
# Out:
#                              City    Lat     Lng  Max Temp  Humidity  \
# 27                        rikitea -23.12 -134.97    71.402      78.0
# 80                           naze  28.37  129.48    78.800      94.0
# 121               fort-shevchenko  44.51   50.26    72.572      56.0
# 158                     shimabara  32.78  130.37    78.008      88.0
# 167                      ajdabiya  30.76   20.23    79.520      59.0
# 204                  north branch  45.51  -92.98    73.994      61.0
# 226                      xiangfan  32.04  112.14    78.260      80.0
# 255                        yining  29.04  114.56    75.848      84.0
# 261                       algiers  36.75    3.04    77.000      78.0
# 270                      bardiyah  31.76   25.09    76.136      80.0
# 285           santiago del estero -27.80  -64.26    76.406      23.0
# 307                     zhoucheng  35.91  116.31    78.170      96.0
# 320                        jishou  28.32  109.72    73.130      84.0
# 323                       shihezi  44.30   86.03    77.234      24.0
# 329  presidencia roque saenz pena -26.79  -60.44    70.448      28.0
# 346                    bandraboua -12.70   45.12    73.400      88.0
# 357                         lefka  35.11   32.85    78.800      60.0
# 411                          sale  34.04   -6.82    71.600      88.0
# 448                        kirkuk  35.47   44.39    76.082      19.0
# 472             icod de los vinos  28.37  -16.71    75.992      90.0
# 475                        anyang  36.10  114.33    77.018      87.0
# 522                        tiznit  29.58   -9.50    71.672      46.0
# 524                          kaka  37.35   59.61    70.142      30.0
# 538                     cruz alta -28.64  -53.61    71.600      46.0
#
#      Cloudiness  Wind Speed Country        Date           Location
# 27          0.0        4.67      PF  08-17-2020  (-23.12, -134.97)
# 80          0.0        1.50      JP  08-17-2020    (28.37, 129.48)
# 121         0.0        7.38      KZ  08-17-2020     (44.51, 50.26)
# 158         0.0        1.59      JP  08-17-2020    (32.78, 130.37)
# 167         0.0        6.58      LY  08-17-2020     (30.76, 20.23)
# 204         0.0        1.79      US  08-17-2020    (45.51, -92.98)
# 226         0.0        2.98      CN  08-17-2020    (32.04, 112.14)
# 255         0.0        0.28      CN  08-17-2020    (29.04, 114.56)
# 261         0.0        2.60      DZ  08-17-2020      (36.75, 3.04)
# 270         0.0        4.15      LY  08-17-2020     (31.76, 25.09)
# 285         0.0        3.07      AR  08-17-2020    (-27.8, -64.26)
# 307         0.0        3.03      CN  08-17-2020    (35.91, 116.31)
# 320         0.0        0.56      CN  08-17-2020    (28.32, 109.72)
# 323         0.0        1.93      CN  08-17-2020      (44.3, 86.03)
# 329         0.0        2.99      AR  08-17-2020   (-26.79, -60.44)
# 346         0.0        0.50      YT  08-17-2020     (-12.7, 45.12)
# 357         0.0        3.60      CY  08-17-2020     (35.11, 32.85)
# 411         0.0        1.50      MA  08-17-2020     (34.04, -6.82)
# 448         0.0        1.10      IQ  08-17-2020     (35.47, 44.39)
# 472         0.0        0.89      ES  08-17-2020    (28.37, -16.71)
# 475         0.0        2.92      CN  08-17-2020     (36.1, 114.33)
# 522         0.0        1.15      MA  08-17-2020      (29.58, -9.5)
# 524         0.0        0.93      TM  08-17-2020     (37.35, 59.61)
# 538         0.0        3.60      BR  08-17-2020   (-28.64, -53.61)

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_vacation_cities.copy()

hotel_df['Hotel Name'] = ''

# %%
hotel_df
# Out:
#                              City    Lat     Lng  Max Temp  Humidity  \
# 27                        rikitea -23.12 -134.97    71.402      78.0
# 80                           naze  28.37  129.48    78.800      94.0
# 121               fort-shevchenko  44.51   50.26    72.572      56.0
# 158                     shimabara  32.78  130.37    78.008      88.0
# 167                      ajdabiya  30.76   20.23    79.520      59.0
# 204                  north branch  45.51  -92.98    73.994      61.0
# 226                      xiangfan  32.04  112.14    78.260      80.0
# 255                        yining  29.04  114.56    75.848      84.0
# 261                       algiers  36.75    3.04    77.000      78.0
# 270                      bardiyah  31.76   25.09    76.136      80.0
# 285           santiago del estero -27.80  -64.26    76.406      23.0
# 307                     zhoucheng  35.91  116.31    78.170      96.0
# 320                        jishou  28.32  109.72    73.130      84.0
# 323                       shihezi  44.30   86.03    77.234      24.0
# 329  presidencia roque saenz pena -26.79  -60.44    70.448      28.0
# 346                    bandraboua -12.70   45.12    73.400      88.0
# 357                         lefka  35.11   32.85    78.800      60.0
# 411                          sale  34.04   -6.82    71.600      88.0
# 448                        kirkuk  35.47   44.39    76.082      19.0
# 472             icod de los vinos  28.37  -16.71    75.992      90.0
# 475                        anyang  36.10  114.33    77.018      87.0
# 522                        tiznit  29.58   -9.50    71.672      46.0
# 524                          kaka  37.35   59.61    70.142      30.0
# 538                     cruz alta -28.64  -53.61    71.600      46.0
#
#      Cloudiness  Wind Speed Country        Date           Location Hotel Name
# 27          0.0        4.67      PF  08-17-2020  (-23.12, -134.97)
# 80          0.0        1.50      JP  08-17-2020    (28.37, 129.48)
# 121         0.0        7.38      KZ  08-17-2020     (44.51, 50.26)
# 158         0.0        1.59      JP  08-17-2020    (32.78, 130.37)
# 167         0.0        6.58      LY  08-17-2020     (30.76, 20.23)
# 204         0.0        1.79      US  08-17-2020    (45.51, -92.98)
# 226         0.0        2.98      CN  08-17-2020    (32.04, 112.14)
# 255         0.0        0.28      CN  08-17-2020    (29.04, 114.56)
# 261         0.0        2.60      DZ  08-17-2020      (36.75, 3.04)
# 270         0.0        4.15      LY  08-17-2020     (31.76, 25.09)
# 285         0.0        3.07      AR  08-17-2020    (-27.8, -64.26)
# 307         0.0        3.03      CN  08-17-2020    (35.91, 116.31)
# 320         0.0        0.56      CN  08-17-2020    (28.32, 109.72)
# 323         0.0        1.93      CN  08-17-2020      (44.3, 86.03)
# 329         0.0        2.99      AR  08-17-2020   (-26.79, -60.44)
# 346         0.0        0.50      YT  08-17-2020     (-12.7, 45.12)
# 357         0.0        3.60      CY  08-17-2020     (35.11, 32.85)
# 411         0.0        1.50      MA  08-17-2020     (34.04, -6.82)
# 448         0.0        1.10      IQ  08-17-2020     (35.47, 44.39)
# 472         0.0        0.89      ES  08-17-2020    (28.37, -16.71)
# 475         0.0        2.92      CN  08-17-2020     (36.1, 114.33)
# 522         0.0        1.15      MA  08-17-2020      (29.58, -9.5)
# 524         0.0        0.93      TM  08-17-2020     (37.35, 59.61)
# 538         0.0        3.60      BR  08-17-2020   (-28.64, -53.61)

# %%
params = {
    'radius' : 5000,
    'type' : 'lodging',
    'key' : g_key
}

# %%
for index, row in hotel_df.iterrows():
    lat = row['Lat']
    long = row['Lng']
    
    params['location'] = f"{lat},{long}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    hotel_request = requests.get(base_url, params = params).json()
    
    try:
        hotel_df.loc[index, 'Hotel Name'] = hotel_request['results'][0]['name']
        
    except (KeyError, IndexError):
        print("Hotel not found. Skipping......")
# Out:
# Hotel not found. Skipping......
# Hotel not found. Skipping......

# %%
hotel_df
# Out:
#                              City    Lat     Lng  Max Temp  Humidity  \
# 27                        rikitea -23.12 -134.97    71.402      78.0
# 80                           naze  28.37  129.48    78.800      94.0
# 121               fort-shevchenko  44.51   50.26    72.572      56.0
# 158                     shimabara  32.78  130.37    78.008      88.0
# 167                      ajdabiya  30.76   20.23    79.520      59.0
# 204                  north branch  45.51  -92.98    73.994      61.0
# 226                      xiangfan  32.04  112.14    78.260      80.0
# 255                        yining  29.04  114.56    75.848      84.0
# 261                       algiers  36.75    3.04    77.000      78.0
# 270                      bardiyah  31.76   25.09    76.136      80.0
# 285           santiago del estero -27.80  -64.26    76.406      23.0
# 307                     zhoucheng  35.91  116.31    78.170      96.0
# 320                        jishou  28.32  109.72    73.130      84.0
# 323                       shihezi  44.30   86.03    77.234      24.0
# 329  presidencia roque saenz pena -26.79  -60.44    70.448      28.0
# 346                    bandraboua -12.70   45.12    73.400      88.0
# 357                         lefka  35.11   32.85    78.800      60.0
# 411                          sale  34.04   -6.82    71.600      88.0
# 448                        kirkuk  35.47   44.39    76.082      19.0
# 472             icod de los vinos  28.37  -16.71    75.992      90.0
# 475                        anyang  36.10  114.33    77.018      87.0
# 522                        tiznit  29.58   -9.50    71.672      46.0
# 524                          kaka  37.35   59.61    70.142      30.0
# 538                     cruz alta -28.64  -53.61    71.600      46.0
#
#      Cloudiness  Wind Speed Country        Date           Location  \
# 27          0.0        4.67      PF  08-17-2020  (-23.12, -134.97)
# 80          0.0        1.50      JP  08-17-2020    (28.37, 129.48)
# 121         0.0        7.38      KZ  08-17-2020     (44.51, 50.26)
# 158         0.0        1.59      JP  08-17-2020    (32.78, 130.37)
# 167         0.0        6.58      LY  08-17-2020     (30.76, 20.23)
# 204         0.0        1.79      US  08-17-2020    (45.51, -92.98)
# 226         0.0        2.98      CN  08-17-2020    (32.04, 112.14)
# 255         0.0        0.28      CN  08-17-2020    (29.04, 114.56)
# 261         0.0        2.60      DZ  08-17-2020      (36.75, 3.04)
# 270         0.0        4.15      LY  08-17-2020     (31.76, 25.09)
# 285         0.0        3.07      AR  08-17-2020    (-27.8, -64.26)
# 307         0.0        3.03      CN  08-17-2020    (35.91, 116.31)
# 320         0.0        0.56      CN  08-17-2020    (28.32, 109.72)
# 323         0.0        1.93      CN  08-17-2020      (44.3, 86.03)
# 329         0.0        2.99      AR  08-17-2020   (-26.79, -60.44)
# 346         0.0        0.50      YT  08-17-2020     (-12.7, 45.12)
# 357         0.0        3.60      CY  08-17-2020     (35.11, 32.85)
# 411         0.0        1.50      MA  08-17-2020     (34.04, -6.82)
# 448         0.0        1.10      IQ  08-17-2020     (35.47, 44.39)
# 472         0.0        0.89      ES  08-17-2020    (28.37, -16.71)
# 475         0.0        2.92      CN  08-17-2020     (36.1, 114.33)
# 522         0.0        1.15      MA  08-17-2020      (29.58, -9.5)
# 524         0.0        0.93      TM  08-17-2020     (37.35, 59.61)
# 538         0.0        3.60      BR  08-17-2020   (-28.64, -53.61)
#
#                                       Hotel Name
# 27                                Pension Maro'i
# 80                                   奄美ポートタワーホテル
# 121                          Oasis hotel Bautino
# 158                                Hotel Nampuro
# 167                                 فندق التوجان
# 204            AmericInn by Wyndham North Branch
# 226                 Xiangyang Wanda Crowne Plaza
# 255                                Xiushui Hotel
# 261                 Sofitel Algiers Hamma Garden
# 270                                  بورتو بردية
# 285                                 Hotel Urbano
# 307                           Yingbin Restaurant
# 320             7Days Inn Jishou Railway Station
# 323  Home Inn Shihezi Dongwu Road Century Square
# 329                              Hotel Aconcagua
# 346                          Stade de Bandraboua
# 357                                  Direk Hotel
# 411              Hôtel Mercure Rabat Sheherazade
# 448                                 فندق التأميم
# 472                         Hotel Rural El Patio
# 475          Hanting Hotel Anyang Wenfeng Avenue
# 522
# 524
# 538                                Hotel Linassi

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
